# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv('C:\\Users\\KARAN AHIR\\Downloads\\MSD_Features.csv')

# %%
df1
# Out:
#                           0                                    1  \
# 0          Sonora Santanera  Las Numero 1 De La Sonora Santanera
# 1              JennyAnyKind                           I Need You
# 2                    Casual                          Fear Itself
# 3     Jeff And Sheri Easter                         Ordinary Day
# 4     Tweeterfriendly Music                         Gin & Phonic
# ...                     ...                                  ...
# 5598       David Arkenstone              Return Of The Guardians
# 5599              Moonspell                         Sin / Pecado
# 5600    Seventh Day Slumber           Once Upon A Shattered Life
# 5601          It Dies Today                               Sirens
# 5602         Danny Williams                           Collection
#
#                                                 2     3                   4  \
# 0                                 Amor De Cabaret  2016  TRAAADZ128F9348C2E
# 1                                 Young Boy Blues  2000  TRAAAVO128F93133D4
# 2                                I Didn't Mean To  1994  TRAAAAW128F429D538
# 3     The Moon And I (Ordinary Day Album Version)  2006  TRAAAMO128F1481E7F
# 4                                    Drop of Rain  2003  TRAAAPK128E0786D96
# ...                                           ...   ...                 ...
# 5598                          The Forgotten Lands  1996  TRBIJIA128F425F57D
# 5599                               The Hanged Man  1998  TRBIJMU12903CF892B
# 5600                               Shattered Life  2005  TRBIJYB128F14AE326
# 5601                  One the road (to Damnation)  2006  TRBIJFB128F92ED124
# 5602             The Wonderful World Of The Young  1998  TRBIJNF128F14815A7
#
#                            5  danceability  energy  key  loudness  mode  \
# 0     5JeyXbf7CrVQ8DqwFikN0P         0.699   0.519    8    -6.422     1
# 1     5uN6oY2NGLC6GKoywHKkZA         0.458   0.570    5    -9.159     0
# 2     01TR6aAKrA2cI3Z0gnCOsu         0.751   0.549    6   -10.508     0
# 3     7ERvcsBBYzSHqQQqlI9xAN         0.456   0.472    5    -8.328     1
# 4     6dfppQDZQ4x3fCs6N89kV3         0.498   0.300    7   -10.716     1
# ...                      ...           ...     ...  ...       ...   ...
# 5598  7xV2k7FEMtUT4IUu4L87it         0.562   0.525    9   -14.594     1
# 5599  3e0tyTV5FiV1bcYeRjdDz2         0.404   0.636    4    -8.798     0
# 5600  2CQwzG5nbS7ys8CHSlavVg         0.406   0.895    2    -5.282     0
# 5601  0MS1NrmBWaCpPLFEXV0VMZ         0.329   0.963    4    -3.501     1
# 5602  62wqW6Q9eTozrruWPt9Z9i         0.194   0.251    8   -12.959     1
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.0290      0.689000          0.000471    0.9350   0.6760  102.463
# 1          0.0495      0.000055          0.000768    0.0988   0.2030  146.609
# 2          0.4290      0.063000          0.000025    0.1060   0.5530   92.224
# 3          0.0325      0.706000          0.000005    0.0833   0.2860  147.565
# 4          0.0352      0.553000          0.000116    0.0963   0.1850  100.315
# ...           ...           ...               ...       ...      ...      ...
# 5598       0.0283      0.456000          0.883000    0.3110   0.7130  141.957
# 5599       0.0325      0.064300          0.653000    0.0795   0.0979  140.105
# 5600       0.0563      0.000429          0.000032    0.1200   0.2780  150.326
# 5601       0.1450      0.000019          0.001380    0.2220   0.2050  116.847
# 5602       0.0371      0.944000          0.000000    0.0997   0.3100  179.310
#
#       duration_ms
# 0          183027
# 1          218907
# 2          218933
# 3          267640
# 4          189560
# ...           ...
# 5598       314533
# 5599       386333
# 5600       209693
# 5601       179413
# 5602       169333
#
# [5603 rows x 18 columns]

# %%
df1.drop(columns=['4'],inplace=True)
df1.head()
# Out:
#                        0                                    1  \
# 0       Sonora Santanera  Las Numero 1 De La Sonora Santanera
# 1           JennyAnyKind                           I Need You
# 2                 Casual                          Fear Itself
# 3  Jeff And Sheri Easter                         Ordinary Day
# 4  Tweeterfriendly Music                         Gin & Phonic
#
#                                              2     3                       5  \
# 0                              Amor De Cabaret  2016  5JeyXbf7CrVQ8DqwFikN0P
# 1                              Young Boy Blues  2000  5uN6oY2NGLC6GKoywHKkZA
# 2                             I Didn't Mean To  1994  01TR6aAKrA2cI3Z0gnCOsu
# 3  The Moon And I (Ordinary Day Album Version)  2006  7ERvcsBBYzSHqQQqlI9xAN
# 4                                 Drop of Rain  2003  6dfppQDZQ4x3fCs6N89kV3
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.699   0.519    8    -6.422     1       0.0290      0.689000
# 1         0.458   0.570    5    -9.159     0       0.0495      0.000055
# 2         0.751   0.549    6   -10.508     0       0.4290      0.063000
# 3         0.456   0.472    5    -8.328     1       0.0325      0.706000
# 4         0.498   0.300    7   -10.716     1       0.0352      0.553000
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000471    0.9350    0.676  102.463       183027
# 1          0.000768    0.0988    0.203  146.609       218907
# 2          0.000025    0.1060    0.553   92.224       218933
# 3          0.000005    0.0833    0.286  147.565       267640
# 4          0.000116    0.0963    0.185  100.315       189560

# %%
df1.rename(columns={'0':'Artist','1':'Album','2':'Track','3':'year','5':'ID'},inplace=True)

# %%
df1
# Out:
#                      Artist                                Album  \
# 0          Sonora Santanera  Las Numero 1 De La Sonora Santanera
# 1              JennyAnyKind                           I Need You
# 2                    Casual                          Fear Itself
# 3     Jeff And Sheri Easter                         Ordinary Day
# 4     Tweeterfriendly Music                         Gin & Phonic
# ...                     ...                                  ...
# 5598       David Arkenstone              Return Of The Guardians
# 5599              Moonspell                         Sin / Pecado
# 5600    Seventh Day Slumber           Once Upon A Shattered Life
# 5601          It Dies Today                               Sirens
# 5602         Danny Williams                           Collection
#
#                                             Track  year  \
# 0                                 Amor De Cabaret  2016
# 1                                 Young Boy Blues  2000
# 2                                I Didn't Mean To  1994
# 3     The Moon And I (Ordinary Day Album Version)  2006
# 4                                    Drop of Rain  2003
# ...                                           ...   ...
# 5598                          The Forgotten Lands  1996
# 5599                               The Hanged Man  1998
# 5600                               Shattered Life  2005
# 5601                  One the road (to Damnation)  2006
# 5602             The Wonderful World Of The Young  1998
#
#                           ID  danceability  energy  key  loudness  mode  \
# 0     5JeyXbf7CrVQ8DqwFikN0P         0.699   0.519    8    -6.422     1
# 1     5uN6oY2NGLC6GKoywHKkZA         0.458   0.570    5    -9.159     0
# 2     01TR6aAKrA2cI3Z0gnCOsu         0.751   0.549    6   -10.508     0
# 3     7ERvcsBBYzSHqQQqlI9xAN         0.456   0.472    5    -8.328     1
# 4     6dfppQDZQ4x3fCs6N89kV3         0.498   0.300    7   -10.716     1
# ...                      ...           ...     ...  ...       ...   ...
# 5598  7xV2k7FEMtUT4IUu4L87it         0.562   0.525    9   -14.594     1
# 5599  3e0tyTV5FiV1bcYeRjdDz2         0.404   0.636    4    -8.798     0
# 5600  2CQwzG5nbS7ys8CHSlavVg         0.406   0.895    2    -5.282     0
# 5601  0MS1NrmBWaCpPLFEXV0VMZ         0.329   0.963    4    -3.501     1
# 5602  62wqW6Q9eTozrruWPt9Z9i         0.194   0.251    8   -12.959     1
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.0290      0.689000          0.000471    0.9350   0.6760  102.463
# 1          0.0495      0.000055          0.000768    0.0988   0.2030  146.609
# 2          0.4290      0.063000          0.000025    0.1060   0.5530   92.224
# 3          0.0325      0.706000          0.000005    0.0833   0.2860  147.565
# 4          0.0352      0.553000          0.000116    0.0963   0.1850  100.315
# ...           ...           ...               ...       ...      ...      ...
# 5598       0.0283      0.456000          0.883000    0.3110   0.7130  141.957
# 5599       0.0325      0.064300          0.653000    0.0795   0.0979  140.105
# 5600       0.0563      0.000429          0.000032    0.1200   0.2780  150.326
# 5601       0.1450      0.000019          0.001380    0.2220   0.2050  116.847
# 5602       0.0371      0.944000          0.000000    0.0997   0.3100  179.310
#
#       duration_ms
# 0          183027
# 1          218907
# 2          218933
# 3          267640
# 4          189560
# ...           ...
# 5598       314533
# 5599       386333
# 5600       209693
# 5601       179413
# 5602       169333
#
# [5603 rows x 17 columns]

# %%
print(pd.unique(df1['mode']))
# Out:
# [1 0]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5603 entries, 0 to 5602
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            5603 non-null   object
#  1   Album             5603 non-null   object
#  2   Track             5603 non-null   object
#  3   year              5603 non-null   int64
#  4   ID                5603 non-null   object
#  5   danceability      5603 non-null   float64
#  6   energy            5603 non-null   float64
#  7   key               5603 non-null   int64
#  8   loudness          5603 non-null   float64
#  9   mode              5603 non-null   int64
#  10  speechiness       5603 non-null   float64
#  11  acousticness      5603 non-null   float64
#  12  instrumentalness  5603 non-null   float64
#  13  liveness          5603 non-null   float64
#  14  valence           5603 non-null   float64
#  15  tempo             5603 non-null   float64
#  16  duration_ms       5603 non-null   int64
# dtypes: float64(9), int64(4), object(4)
# memory usage: 744.3+ KB

# %%
df2=pd.read_csv('C:\\Users\\KARAN AHIR\\Downloads\\BillBoard_Features.csv')
df2.head()
# Out:
#            Track               Artist               SpotifyID  danceability  \
# 0   Lucid Dreams           Juice WRLD  285pBltuF7vW8TeWk8hdRR         0.511
# 1     Better Now          Post Malone  7dt6x5M1jzdTEt8oCbisTK         0.680
# 2  Drip Too Hard     Lil Baby & Gunna  78QR3Wp35dqAhFEc2qAGjE         0.897
# 3     Sicko Mode         Travis Scott  2xLMifQCjDGFmkHkpNLD9h         0.834
# 4     Youngblood  5 Seconds Of Summer  2iUXsYOEPhVqEBwsqP70rE         0.596
#
#    energy  key  speechiness  acousticness  instrumentalness  liveness  \
# 0   0.566    6        0.200       0.34900               0.0     0.340
# 1   0.578   10        0.040       0.33100               0.0     0.135
# 2   0.662    1        0.292       0.08520               0.0     0.534
# 3   0.730    8        0.222       0.00513               0.0     0.124
# 4   0.854    7        0.463       0.01690               0.0     0.124
#
#    valence    tempo  duration_ms  loudness  mode
# 0    0.218   83.903       239836    -7.230   0.0
# 1    0.341  145.038       231267    -5.804   1.0
# 2    0.389  112.511       145543    -6.903   0.0
# 3    0.446  155.008       312820    -3.714   1.0
# 4    0.152  120.274       203418    -5.114   0.0

# %%
df2.rename(columns={'SpotifyID':'ID'},inplace=True)
df2.head()
# Out:
#            Track               Artist                      ID  danceability  \
# 0   Lucid Dreams           Juice WRLD  285pBltuF7vW8TeWk8hdRR         0.511
# 1     Better Now          Post Malone  7dt6x5M1jzdTEt8oCbisTK         0.680
# 2  Drip Too Hard     Lil Baby & Gunna  78QR3Wp35dqAhFEc2qAGjE         0.897
# 3     Sicko Mode         Travis Scott  2xLMifQCjDGFmkHkpNLD9h         0.834
# 4     Youngblood  5 Seconds Of Summer  2iUXsYOEPhVqEBwsqP70rE         0.596
#
#    energy  key  speechiness  acousticness  instrumentalness  liveness  \
# 0   0.566    6        0.200       0.34900               0.0     0.340
# 1   0.578   10        0.040       0.33100               0.0     0.135
# 2   0.662    1        0.292       0.08520               0.0     0.534
# 3   0.730    8        0.222       0.00513               0.0     0.124
# 4   0.854    7        0.463       0.01690               0.0     0.124
#
#    valence    tempo  duration_ms  loudness  mode
# 0    0.218   83.903       239836    -7.230   0.0
# 1    0.341  145.038       231267    -5.804   1.0
# 2    0.389  112.511       145543    -6.903   0.0
# 3    0.446  155.008       312820    -3.714   1.0
# 4    0.152  120.274       203418    -5.114   0.0

# %%
print(pd.unique(df2['mode']))
# Out:
# [ 0.  1. nan]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9329 entries, 0 to 9328
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track             9328 non-null   object
#  1   Artist            9327 non-null   object
#  2   ID                9329 non-null   object
#  3   danceability      9329 non-null   float64
#  4   energy            9329 non-null   float64
#  5   key               9329 non-null   int64
#  6   speechiness       9329 non-null   float64
#  7   acousticness      9329 non-null   float64
#  8   instrumentalness  9329 non-null   float64
#  9   liveness          9329 non-null   float64
#  10  valence           9329 non-null   float64
#  11  tempo             9329 non-null   float64
#  12  duration_ms       9329 non-null   int64
#  13  loudness          9329 non-null   float64
#  14  mode              9319 non-null   float64
# dtypes: float64(10), int64(2), object(3)
# memory usage: 1.1+ MB

# %%
MSD_Billboard=pd.concat([df1,df2],axis=0,ignore_index=True)

# %%
MSD_Billboard
# Out:
#                               Artist                                Album  \
# 0                   Sonora Santanera  Las Numero 1 De La Sonora Santanera
# 1                       JennyAnyKind                           I Need You
# 2                             Casual                          Fear Itself
# 3              Jeff And Sheri Easter                         Ordinary Day
# 4              Tweeterfriendly Music                         Gin & Phonic
# ...                              ...                                  ...
# 14927                The 2 Live Crew                                  NaN
# 14928   Technotronic Featuring Felly                                  NaN
# 14929   Mantronix Featuring Wondress                                  NaN
# 14930  Entouch Featuring Keith Sweat                                  NaN
# 14931      Prince With Sheena Easton                                  NaN
#
#                                              Track    year  \
# 0                                  Amor De Cabaret  2016.0
# 1                                  Young Boy Blues  2000.0
# 2                                 I Didn't Mean To  1994.0
# 3      The Moon And I (Ordinary Day Album Version)  2006.0
# 4                                     Drop of Rain  2003.0
# ...                                            ...     ...
# 14927                                  Me So Horny     NaN
# 14928                              Pump Up The Jam     NaN
# 14929                        Got To Have Your Love     NaN
# 14930                                     All Nite     NaN
# 14931                            The Arms Of Orion     NaN
#
#                            ID  danceability  energy  key  loudness  mode  \
# 0      5JeyXbf7CrVQ8DqwFikN0P         0.699   0.519    8    -6.422   1.0
# 1      5uN6oY2NGLC6GKoywHKkZA         0.458   0.570    5    -9.159   0.0
# 2      01TR6aAKrA2cI3Z0gnCOsu         0.751   0.549    6   -10.508   0.0
# 3      7ERvcsBBYzSHqQQqlI9xAN         0.456   0.472    5    -8.328   1.0
# 4      6dfppQDZQ4x3fCs6N89kV3         0.498   0.300    7   -10.716   1.0
# ...                       ...           ...     ...  ...       ...   ...
# 14927  6rQ9ypCfSRZs2AqqobvXu3         0.893   0.523    1   -11.157   NaN
# 14928  0UAEHlFR79k9CJvknSGUNf         0.867   0.911   10    -7.375   NaN
# 14929  7MZzwdBfX8Dq0xFLFfxtdJ         0.763   0.505   10   -13.669   NaN
# 14930  6q989QMsV87X9Em9J6DONi         0.834   0.485   11   -13.040   NaN
# 14931  0YcUNHmnt35v7J7amKvgR4         0.604   0.316    2   -14.674   NaN
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 0           0.0290      0.689000          0.000471    0.9350    0.676
# 1           0.0495      0.000055          0.000768    0.0988    0.203
# 2           0.4290      0.063000          0.000025    0.1060    0.553
# 3           0.0325      0.706000          0.000005    0.0833    0.286
# 4           0.0352      0.553000          0.000116    0.0963    0.185
# ...            ...           ...               ...       ...      ...
# 14927       0.0986      0.003360          0.000500    0.0833    0.949
# 14928       0.1150      0.023900          0.000000    0.0491    0.675
# 14929       0.0753      0.179000          0.001070    0.0497    0.960
# 14930       0.0453      0.047800          0.000051    0.1030    0.929
# 14931       0.0302      0.560000          0.000012    0.0905    0.391
#
#          tempo  duration_ms
# 0      102.463       183027
# 1      146.609       218907
# 2       92.224       218933
# 3      147.565       267640
# 4      100.315       189560
# ...        ...          ...
# 14927  132.737       260441
# 14928  124.810       215040
# 14929  105.632       383333
# 14930  107.598       368467
# 14931  129.693       302973
#
# [14932 rows x 17 columns]

# %%
MSD_Billboard.shape
# Out:
# (14932, 17)

# %%
MSD_Billboard.dropna(subset=['mode'],how='any',inplace=True)

# %%
MSD_Billboard1 = MSD_Billboard[MSD_Billboard['mode']!=-999]
print('mode values')
print(MSD_Billboard1['mode'].value_counts())
MSD_Billboard1.shape
# Out:
# mode values
# 1.0    10058
# 0.0     4864
# Name: mode, dtype: int64
# (14922, 17)

# %%
print(pd.unique(MSD_Billboard1['mode']))
# Out:
# [1. 0.]

# %%
(set(MSD_Billboard1['mode']))
# Out:
# {0.0, 1.0}

# %%
print(MSD_Billboard1['mode'].value_counts())
# Out:
# 1.0    10058
# 0.0     4864
# Name: mode, dtype: int64

# %%
MSD_Billboard1.drop_duplicates(subset='Track',keep=False,inplace=True)
MSD_Billboard1.head()
# Out:
#                   Artist                                Album  \
# 0       Sonora Santanera  Las Numero 1 De La Sonora Santanera
# 1           JennyAnyKind                           I Need You
# 2                 Casual                          Fear Itself
# 3  Jeff And Sheri Easter                         Ordinary Day
# 4  Tweeterfriendly Music                         Gin & Phonic
#
#                                          Track    year  \
# 0                              Amor De Cabaret  2016.0
# 1                              Young Boy Blues  2000.0
# 2                             I Didn't Mean To  1994.0
# 3  The Moon And I (Ordinary Day Album Version)  2006.0
# 4                                 Drop of Rain  2003.0
#
#                        ID  danceability  energy  key  loudness  mode  \
# 0  5JeyXbf7CrVQ8DqwFikN0P         0.699   0.519    8    -6.422   1.0
# 1  5uN6oY2NGLC6GKoywHKkZA         0.458   0.570    5    -9.159   0.0
# 2  01TR6aAKrA2cI3Z0gnCOsu         0.751   0.549    6   -10.508   0.0
# 3  7ERvcsBBYzSHqQQqlI9xAN         0.456   0.472    5    -8.328   1.0
# 4  6dfppQDZQ4x3fCs6N89kV3         0.498   0.300    7   -10.716   1.0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0290      0.689000          0.000471    0.9350    0.676  102.463
# 1       0.0495      0.000055          0.000768    0.0988    0.203  146.609
# 2       0.4290      0.063000          0.000025    0.1060    0.553   92.224
# 3       0.0325      0.706000          0.000005    0.0833    0.286  147.565
# 4       0.0352      0.553000          0.000116    0.0963    0.185  100.315
#
#    duration_ms
# 0       183027
# 1       218907
# 2       218933
# 3       267640
# 4       189560

# %%
MSD_Billboard1.shape
# Out:
# (12122, 17)

# %%
MSD_Billboard1.isnull().sum()
# Out:
# Artist                 2
# Album               7161
# Track                  1
# year                7161
# ID                     0
# danceability           0
# energy                 0
# key                    0
# loudness               0
# mode                   0
# speechiness            0
# acousticness           0
# instrumentalness       0
# liveness               0
# valence                0
# tempo                  0
# duration_ms            0
# dtype: int64

# %%
MSD_Billboard1.isnull().sum()*100/MSD_Billboard1.shape[0]
# Out:
# Artist               0.016499
# Album               59.074410
# Track                0.008249
# year                59.074410
# ID                   0.000000
# danceability         0.000000
# energy               0.000000
# key                  0.000000
# loudness             0.000000
# mode                 0.000000
# speechiness          0.000000
# acousticness         0.000000
# instrumentalness     0.000000
# liveness             0.000000
# valence              0.000000
# tempo                0.000000
# duration_ms          0.000000
# dtype: float64

# %%
sns.heatmap(MSD_Billboard1.isnull())
plt.show()

# %%
MSD_Billboard1.shape
# Out:
# (12122, 17)

# %%
MSD_Billboard1.isnull().sum()
# Out:
# Artist                 2
# Album               7161
# Track                  1
# year                7161
# ID                     0
# danceability           0
# energy                 0
# key                    0
# loudness               0
# mode                   0
# speechiness            0
# acousticness           0
# instrumentalness       0
# liveness               0
# valence                0
# tempo                  0
# duration_ms            0
# dtype: int64

# %%
MSD_Billboard1.drop(columns=['year'],inplace=True)

# %%
MSD_Billboard1.shape
# Out:
# (12122, 16)

# %%
MSD_Billboard1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12122 entries, 0 to 14921
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            12120 non-null  object
#  1   Album             4961 non-null   object
#  2   Track             12121 non-null  object
#  3   ID                12122 non-null  object
#  4   danceability      12122 non-null  float64
#  5   energy            12122 non-null  float64
#  6   key               12122 non-null  int64
#  7   loudness          12122 non-null  float64
#  8   mode              12122 non-null  float64
#  9   speechiness       12122 non-null  float64
#  10  acousticness      12122 non-null  float64
#  11  instrumentalness  12122 non-null  float64
#  12  liveness          12122 non-null  float64
#  13  valence           12122 non-null  float64
#  14  tempo             12122 non-null  float64
#  15  duration_ms       12122 non-null  int64
# dtypes: float64(10), int64(2), object(4)
# memory usage: 1.6+ MB

# %%
MSD_Billboard1.isnull().sum()
# Out:
# ID                  0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# dtype: int64

# %%
MSD_Billboard1.drop_duplicates(subset='ID', keep =False, inplace=True)
MSD_Billboard1.shape
# Out:
# (12098, 15)

# %%
 from sklearn.model_selection import train_test_split

# %%
MSD_Billboard1.columns
# Out:
# Index(['ID', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms'],
#       dtype='object')

# %%
print(MSD_Billboard1['mode'].value_counts())
# Out:
# 1.0    8158
# 0.0    3940
# Name: mode, dtype: int64

# %%
MSD_Billboard1.pop('ID')
MSD_Billboard1.rename(columns={'mode':'hit'}, inplace = True)
target_column = MSD_Billboard1.pop('hit')
MSD_Billboard1.insert(11,'hit',target_column)
Dff1= MSD_Billboard1
Dff1.head()
# Out:
#    danceability  energy  key  loudness  speechiness  acousticness  \
# 0         0.699   0.519    8    -6.422       0.0290      0.689000
# 1         0.458   0.570    5    -9.159       0.0495      0.000055
# 2         0.751   0.549    6   -10.508       0.4290      0.063000
# 3         0.456   0.472    5    -8.328       0.0325      0.706000
# 4         0.498   0.300    7   -10.716       0.0352      0.553000
#
#    instrumentalness  liveness  valence    tempo  duration_ms  hit
# 0          0.000471    0.9350    0.676  102.463       183027  1.0
# 1          0.000768    0.0988    0.203  146.609       218907  0.0
# 2          0.000025    0.1060    0.553   92.224       218933  0.0
# 3          0.000005    0.0833    0.286  147.565       267640  1.0
# 4          0.000116    0.0963    0.185  100.315       189560  1.0

# %%
X = Dff1.iloc[:,:11]
y = Dff1.hit

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X,y,test_size=0.25)
y_train.shape
# Out:
# (9073,)

# %%
from sklearn import ensemble
rf_classifier= ensemble.RandomForestClassifier()
rf_classifier.fit(X_train,y_train)
rf_classifier.score(X_test,y_test)
# Out:
# 0.6634710743801653

# %%
from sklearn.svm import SVC
sv_clf=SVC(probability=True)
sv_clf.fit(X_train,y_train)
sv_clf.score(X_test,y_test)
# Out:
# 0.6704132231404959
