# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
import chardet
with open('MSD_Features.csv', 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.7290861037696481, 'language': ''}

# %%
df1=pd.read_csv('MSD_Features.csv',encoding= 'ISO-8859-1')
df1.head()
# Out:
#                        0                                    1  \
# 0       Sonora Santanera  Las Numero 1 De La Sonora Santanera
# 1           JennyAnyKind                           I Need You
# 2                 Casual                          Fear Itself
# 3  Jeff And Sheri Easter                         Ordinary Day
# 4  Tweeterfriendly Music                         Gin & Phonic
#
#                                              2     3                   4  \
# 0                              Amor De Cabaret  2016  TRAAADZ128F9348C2E
# 1                              Young Boy Blues  2000  TRAAAVO128F93133D4
# 2                             I Didn't Mean To  1994  TRAAAAW128F429D538
# 3  The Moon And I (Ordinary Day Album Version)  2006  TRAAAMO128F1481E7F
# 4                                 Drop of Rain  2003  TRAAAPK128E0786D96
#
#                         5  danceability  energy  key  loudness  mode  \
# 0  5JeyXbf7CrVQ8DqwFikN0P         0.699   0.519    8    -6.422     1
# 1  5uN6oY2NGLC6GKoywHKkZA         0.458   0.570    5    -9.159     0
# 2  01TR6aAKrA2cI3Z0gnCOsu         0.751   0.549    6   -10.508     0
# 3  7ERvcsBBYzSHqQQqlI9xAN         0.456   0.472    5    -8.328     1
# 4  6dfppQDZQ4x3fCs6N89kV3         0.498   0.300    7   -10.716     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0290      0.689000          0.000471    0.9350    0.676  102.463
# 1       0.0495      0.000055          0.000768    0.0988    0.203  146.609
# 2       0.4290      0.063000          0.000025    0.1060    0.553   92.224
# 3       0.0325      0.706000          0.000005    0.0833    0.286  147.565
# 4       0.0352      0.553000          0.000116    0.0963    0.185  100.315
#
#    duration_ms
# 0       183027
# 1       218907
# 2       218933
# 3       267640
# 4       189560

# %%
df1['ID']=df1[['4','5']].apply(lambda x: ' '.join(x),axis=1)
df1=df1.rename({'0':'Artist','1':'Album','2':'Track','3':'Year'},axis=1)

# %%
df1.drop(['4','5'],axis=1,inplace=True)
df1.head()
# Out:
#                   Artist                                Album  \
# 0       Sonora Santanera  Las Numero 1 De La Sonora Santanera
# 1           JennyAnyKind                           I Need You
# 2                 Casual                          Fear Itself
# 3  Jeff And Sheri Easter                         Ordinary Day
# 4  Tweeterfriendly Music                         Gin & Phonic
#
#                                          Track  Year  danceability  energy  \
# 0                              Amor De Cabaret  2016         0.699   0.519
# 1                              Young Boy Blues  2000         0.458   0.570
# 2                             I Didn't Mean To  1994         0.751   0.549
# 3  The Moon And I (Ordinary Day Album Version)  2006         0.456   0.472
# 4                                 Drop of Rain  2003         0.498   0.300
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    8    -6.422     1       0.0290      0.689000          0.000471    0.9350
# 1    5    -9.159     0       0.0495      0.000055          0.000768    0.0988
# 2    6   -10.508     0       0.4290      0.063000          0.000025    0.1060
# 3    5    -8.328     1       0.0325      0.706000          0.000005    0.0833
# 4    7   -10.716     1       0.0352      0.553000          0.000116    0.0963
#
#    valence    tempo  duration_ms                                         ID
# 0    0.676  102.463       183027  TRAAADZ128F9348C2E 5JeyXbf7CrVQ8DqwFikN0P
# 1    0.203  146.609       218907  TRAAAVO128F93133D4 5uN6oY2NGLC6GKoywHKkZA
# 2    0.553   92.224       218933  TRAAAAW128F429D538 01TR6aAKrA2cI3Z0gnCOsu
# 3    0.286  147.565       267640  TRAAAMO128F1481E7F 7ERvcsBBYzSHqQQqlI9xAN
# 4    0.185  100.315       189560  TRAAAPK128E0786D96 6dfppQDZQ4x3fCs6N89kV3

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5603 entries, 0 to 5602
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            5603 non-null   object
#  1   Album             5603 non-null   object
#  2   Track             5603 non-null   object
#  3   Year              5603 non-null   int64
#  4   danceability      5603 non-null   float64
#  5   energy            5603 non-null   float64
#  6   key               5603 non-null   int64
#  7   loudness          5603 non-null   float64
#  8   mode              5603 non-null   int64
#  9   speechiness       5603 non-null   float64
#  10  acousticness      5603 non-null   float64
#  11  instrumentalness  5603 non-null   float64
#  12  liveness          5603 non-null   float64
#  13  valence           5603 non-null   float64
#  14  tempo             5603 non-null   float64
#  15  duration_ms       5603 non-null   int64
#  16  ID                5603 non-null   object
# dtypes: float64(9), int64(4), object(4)
# memory usage: 744.3+ KB

# %%
df2=pd.read_csv('BillBoard_Features.csv')
df2.head()
# Out:
#            Track               Artist               SpotifyID  danceability  \
# 0   Lucid Dreams           Juice WRLD  285pBltuF7vW8TeWk8hdRR         0.511
# 1     Better Now          Post Malone  7dt6x5M1jzdTEt8oCbisTK         0.680
# 2  Drip Too Hard     Lil Baby & Gunna  78QR3Wp35dqAhFEc2qAGjE         0.897
# 3     Sicko Mode         Travis Scott  2xLMifQCjDGFmkHkpNLD9h         0.834
# 4     Youngblood  5 Seconds Of Summer  2iUXsYOEPhVqEBwsqP70rE         0.596
#
#    energy  key  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   0.566    6     0        0.200       0.34900               0.0     0.340
# 1   0.578   10     1        0.040       0.33100               0.0     0.135
# 2   0.662    1     0        0.292       0.08520               0.0     0.534
# 3   0.730    8     1        0.222       0.00513               0.0     0.124
# 4   0.854    7     0        0.463       0.01690               0.0     0.124
#
#    valence    tempo  duration_ms  loudness
# 0    0.218   83.903       239836    -7.230
# 1    0.341  145.038       231267    -5.804
# 2    0.389  112.511       145543    -6.903
# 3    0.446  155.008       312820    -3.714
# 4    0.152  120.274       203418    -5.114

# %%
df2.rename(columns={'SpotifyID':'ID'},inplace=True)
df2.head()
# Out:
#            Track               Artist                      ID  danceability  \
# 0   Lucid Dreams           Juice WRLD  285pBltuF7vW8TeWk8hdRR         0.511
# 1     Better Now          Post Malone  7dt6x5M1jzdTEt8oCbisTK         0.680
# 2  Drip Too Hard     Lil Baby & Gunna  78QR3Wp35dqAhFEc2qAGjE         0.897
# 3     Sicko Mode         Travis Scott  2xLMifQCjDGFmkHkpNLD9h         0.834
# 4     Youngblood  5 Seconds Of Summer  2iUXsYOEPhVqEBwsqP70rE         0.596
#
#    energy  key  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   0.566    6     0        0.200       0.34900               0.0     0.340
# 1   0.578   10     1        0.040       0.33100               0.0     0.135
# 2   0.662    1     0        0.292       0.08520               0.0     0.534
# 3   0.730    8     1        0.222       0.00513               0.0     0.124
# 4   0.854    7     0        0.463       0.01690               0.0     0.124
#
#    valence    tempo  duration_ms  loudness
# 0    0.218   83.903       239836    -7.230
# 1    0.341  145.038       231267    -5.804
# 2    0.389  112.511       145543    -6.903
# 3    0.446  155.008       312820    -3.714
# 4    0.152  120.274       203418    -5.114

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9329 entries, 0 to 9328
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track             9328 non-null   object
#  1   Artist            9327 non-null   object
#  2   ID                9329 non-null   object
#  3   danceability      9329 non-null   float64
#  4   energy            9329 non-null   float64
#  5   key               9329 non-null   int64
#  6   mode              9329 non-null   int64
#  7   speechiness       9329 non-null   float64
#  8   acousticness      9329 non-null   float64
#  9   instrumentalness  9329 non-null   float64
#  10  liveness          9329 non-null   float64
#  11  valence           9329 non-null   float64
#  12  tempo             9329 non-null   float64
#  13  duration_ms       9329 non-null   int64
#  14  loudness          9329 non-null   float64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 1.1+ MB

# %%
MSD_Billboard=pd.concat([df1,df2],axis=0,ignore_index=True)

# %%
MSD_Billboard.tail(10)
# Out:
#                                          Artist Album                  Track  \
# 14922  Linda Ronstadt (Featuring Aaron Neville)   NaN            All My Life
# 14923                  Leila K With Rob 'N' Raz   NaN             Got To Get
# 14924                                Young M.C.   NaN             I Come Off
# 14925                                Young M.C.   NaN            Bust A Move
# 14926                    McAuley Schenker Group   NaN                Anytime
# 14927                           The 2 Live Crew   NaN            Me So Horny
# 14928              Technotronic Featuring Felly   NaN        Pump Up The Jam
# 14929              Mantronix Featuring Wondress   NaN  Got To Have Your Love
# 14930             Entouch Featuring Keith Sweat   NaN               All Nite
# 14931                 Prince With Sheena Easton   NaN      The Arms Of Orion
#
#        Year  danceability  energy  key  loudness  mode  speechiness  \
# 14922   NaN         0.602   0.523    3    -8.753     1       0.0340
# 14923   NaN         0.922   0.733    8   -12.590     1       0.0624
# 14924   NaN         0.754   0.906    1    -4.989     1       0.0989
# 14925   NaN         0.946   0.772    4    -7.537     0       0.1210
# 14926   NaN         0.448   0.812    1    -2.897     0       0.0350
# 14927   NaN         0.893   0.523    1   -11.157     1       0.0986
# 14928   NaN         0.867   0.911   10    -7.375     0       0.1150
# 14929   NaN         0.763   0.505   10   -13.669     0       0.0753
# 14930   NaN         0.834   0.485   11   -13.040     1       0.0453
# 14931   NaN         0.604   0.316    2   -14.674     1       0.0302
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 14922       0.44400          0.000005    0.0500   0.3740   74.005
# 14923       0.04850          0.086500    0.3970   0.8610  115.621
# 14924       0.01390          0.000010    0.3320   0.9280   95.467
# 14925       0.05120          0.000002    0.0612   0.7430  116.972
# 14926       0.01260          0.000607    0.1290   0.0632  110.990
# 14927       0.00336          0.000500    0.0833   0.9490  132.737
# 14928       0.02390          0.000000    0.0491   0.6750  124.810
# 14929       0.17900          0.001070    0.0497   0.9600  105.632
# 14930       0.04780          0.000051    0.1030   0.9290  107.598
# 14931       0.56000          0.000012    0.0905   0.3910  129.693
#
#        duration_ms                      ID
# 14922       210960  6mHrQvPTT3i4ZwwcR4gZR2
# 14923       281267  141Cw4LvVrUWn9gHVHOGtx
# 14924       246160  3vlTwuK1urCWqj0PcZIUgZ
# 14925       263914  3IeCYkdKI55mNMl2o4vX0k
# 14926       361081  2f73ZxSCPX65SZCM9oXd4M
# 14927       260441  6rQ9ypCfSRZs2AqqobvXu3
# 14928       215040  0UAEHlFR79k9CJvknSGUNf
# 14929       383333  7MZzwdBfX8Dq0xFLFfxtdJ
# 14930       368467  6q989QMsV87X9Em9J6DONi
# 14931       302973  0YcUNHmnt35v7J7amKvgR4

# %%
MSD_Billboard.shape
# Out:
# (14932, 17)

# %%
MSD_Billboard=MSD_Billboard.sort_values('Track')

# %%
MSD_Billboard.head()
# Out:
#                                   Artist Album       Track  Year  \
# 12691                 Young And Restless   NaN   "B" Girls   NaN
# 10053                              Nelly   NaN          #1   NaN
# 13589      Mariah Carey Featuring Miguel   NaN  #Beautiful   NaN
# 6949                    The Chainsmokers   NaN     #SELFIE   NaN
# 13606  will.i.am Featuring Justin Bieber   NaN  #thatPOWER   NaN
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 12691         0.615   0.497    7   -11.913     1       0.4390       0.01600
# 10053         0.690   0.592    7    -5.973     1       0.3000       0.02360
# 13589         0.677   0.749    4    -5.405     1       0.0391       0.34600
# 6949          0.789   0.915    0    -3.263     1       0.2480       0.01350
# 13606         0.797   0.608    6    -6.096     0       0.0583       0.00112
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 12691          0.000000    0.3120    0.769  193.762       242107
# 10053          0.000000    0.5600    0.466  179.980       198760
# 13589          0.000000    0.3470    0.469  107.042       199867
# 6949           0.000009    0.0818    0.660  127.955       183750
# 13606          0.000077    0.0748    0.403  128.000       279507
#
#                            ID
# 12691  0rWUHulFlScxQsCq7kWKde
# 10053  7rSj5gEdN5KgHwbnEVAZ4b
# 13589  617KSbx52ACbnQBxSsG26X
# 6949   1HOlb9rdNOmy9b1Fakicjo
# 13606  01TuObJVd7owWchVRuQbQw

# %%
MSD_Billboard.drop_duplicates(subset='Track',keep=False,inplace=True)
MSD_Billboard.head()
# Out:
#                                   Artist Album       Track  Year  \
# 12691                 Young And Restless   NaN   "B" Girls   NaN
# 10053                              Nelly   NaN          #1   NaN
# 13589      Mariah Carey Featuring Miguel   NaN  #Beautiful   NaN
# 6949                    The Chainsmokers   NaN     #SELFIE   NaN
# 13606  will.i.am Featuring Justin Bieber   NaN  #thatPOWER   NaN
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 12691         0.615   0.497    7   -11.913     1       0.4390       0.01600
# 10053         0.690   0.592    7    -5.973     1       0.3000       0.02360
# 13589         0.677   0.749    4    -5.405     1       0.0391       0.34600
# 6949          0.789   0.915    0    -3.263     1       0.2480       0.01350
# 13606         0.797   0.608    6    -6.096     0       0.0583       0.00112
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 12691          0.000000    0.3120    0.769  193.762       242107
# 10053          0.000000    0.5600    0.466  179.980       198760
# 13589          0.000000    0.3470    0.469  107.042       199867
# 6949           0.000009    0.0818    0.660  127.955       183750
# 13606          0.000077    0.0748    0.403  128.000       279507
#
#                            ID
# 12691  0rWUHulFlScxQsCq7kWKde
# 10053  7rSj5gEdN5KgHwbnEVAZ4b
# 13589  617KSbx52ACbnQBxSsG26X
# 6949   1HOlb9rdNOmy9b1Fakicjo
# 13606  01TuObJVd7owWchVRuQbQw

# %%
MSD_Billboard.shape
# Out:
# (12127, 17)

# %%
MSD_Billboard.isnull().sum()
# Out:
# Artist                 2
# Album               7167
# Track                  1
# Year                7167
# danceability           0
# energy                 0
# key                    0
# loudness               0
# mode                   0
# speechiness            0
# acousticness           0
# instrumentalness       0
# liveness               0
# valence                0
# tempo                  0
# duration_ms            0
# ID                     0
# dtype: int64

# %%
(MSD_Billboard.isnull().sum()*100)/MSD_Billboard.shape[0]
# Out:
# Artist               0.016492
# Album               59.099530
# Track                0.008246
# Year                59.099530
# danceability         0.000000
# energy               0.000000
# key                  0.000000
# loudness             0.000000
# mode                 0.000000
# speechiness          0.000000
# acousticness         0.000000
# instrumentalness     0.000000
# liveness             0.000000
# valence              0.000000
# tempo                0.000000
# duration_ms          0.000000
# ID                   0.000000
# dtype: float64

# %%
sns.heatmap(MSD_Billboard.isnull())
plt.show()

# %%
#we have more than 50% of values are null in column Album and Year
#so we remove those columns
MSD_Billboard.drop('Album',axis=1,inplace=True)
MSD_Billboard.drop('Year',axis=1,inplace=True)

# %%
MSD_Billboard.shape
# Out:
# (12127, 15)

# %%
MSD_Billboard=MSD_Billboard.dropna()

# %%
MSD_Billboard.shape
# Out:
# (12125, 15)

# %%
MSD_Billboard.isnull().sum()
# Out:
# Artist              0
# Track               0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# ID                  0
# dtype: int64
